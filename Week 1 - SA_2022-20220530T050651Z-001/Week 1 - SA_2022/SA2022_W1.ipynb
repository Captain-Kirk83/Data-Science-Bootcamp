# %% [markdown]
# # SUMMER ANALYTICS 2022

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# # **Gotta catch 'em all !**

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2022! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about Pokemons.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
#your code here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
#your code here
df=pd.read_csv('SA2022_W1_Pokemon.csv')

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (800, 13)

# %%
#your code here
df.shape
# Out:
# (800, 13)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ### 5) Remove the column '#' and update the dataframe.

# %%
#your code here
df=df.drop('#',1)
print(df.columns)
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')
# /tmp/ipykernel_26011/3803126398.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df=df.drop('#',1)

# %% [markdown]
# ### 6) Set the 'Name' column as the index of dataframe

# %%
#your code here
df.set_index('Name', inplace=True)
df.head()
# Out:
#                       Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              Grass  Poison    318  45      49       49       65
# Ivysaur                Grass  Poison    405  60      62       63       80
# Venusaur               Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# Charmander              Fire     NaN    309  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur                   65     45           1      False
# Ivysaur                     80     60           1      False
# Venusaur                   100     80           1      False
# VenusaurMega Venusaur      120     80           1      False
# Charmander                  50     65           1      False

# %% [markdown]
# ###  7) Print a list of all the unique Type-1 powers

# %%
#your code here
print(df['Type 1'].unique())
# Out:
# ['Grass' 'Fire' 'Water' 'Bug' 'Normal' 'Poison' 'Electric' 'Ground'
#  'Fairy' 'Fighting' 'Psychic' 'Rock' 'Ghost' 'Ice' 'Dragon' 'Dark' 'Steel'
#  'Flying']

# %% [markdown]
# ### 8) Create a column which contains the Type 1 and Type 2 abilities of pokemons, seperated with a '+'' sign. Also, display the no. of pokemons that have type-1 power as 'Psychic' and type 2 power as 'Flying' using this new column.

# %%
#your code here
df['Type'] = df['Type 1'] + df['Type 2']
df.head()
# Out:
#                       Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              Grass  Poison    318  45      49       49       65
# Ivysaur                Grass  Poison    405  60      62       63       80
# Venusaur               Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# Charmander              Fire     NaN    309  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary         Type
# Name
# Bulbasaur                   65     45           1      False  GrassPoison
# Ivysaur                     80     60           1      False  GrassPoison
# Venusaur                   100     80           1      False  GrassPoison
# VenusaurMega Venusaur      120     80           1      False  GrassPoison
# Charmander                  50     65           1      False          NaN

# %%
df.loc[df['Type']=='PsychicFlying'].count()
# Out:
# Type 1        6
# Type 2        6
# Total         6
# HP            6
# Attack        6
# Defense       6
# Sp. Atk       6
# Sp. Def       6
# Speed         6
# Generation    6
# Legendary     6
# Type          6
# dtype: int64

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. How many pokemons have 'Mega' in their name?

# %%
#your code here
df[df.index.str.contains('Mega', regex=False)].count()
# Out:
# Type 1        49
# Type 2        39
# Total         49
# HP            49
# Attack        49
# Defense       49
# Sp. Atk       49
# Sp. Def       49
# Speed         49
# Generation    49
# Legendary     49
# Type          39
# dtype: int64

# %% [markdown]
# ### 2. What is the standard deviation of Sp. Def. in the dataset ?

# %%
#your code here
df.describe()
# Out:
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.00000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   435.10250   69.258750   79.001250   73.842500   72.820000   71.902500
# std    119.96304   25.534669   32.457366   31.183501   32.722294   27.828916
# min    180.00000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    330.00000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    450.00000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    515.00000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    780.00000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %% [markdown]
# ### 3. What percentage (upto 3 decimal places) of pokemons are legendary ?

# %%
#your code here
lrow=df[df['Legendary']].shape[0]
row=df.shape[0]
per=(lrow/row)*100
print("{:.3f}".format(per))
# Out:
# 8.125

# %% [markdown]
# ### 4. Name the pokemon(s) with Maximum Defense.

# %%
#your code here
df[df['Defense']==230]
# Out:
#                     Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# SteelixMega Steelix  Steel  Ground    610  75     125      230       55
# Shuckle                Bug    Rock    505  20      10      230       10
# AggronMega Aggron    Steel     NaN    630  70     140      230       60
#
#                      Sp. Def  Speed  Generation  Legendary         Type
# Name
# SteelixMega Steelix       95     30           2      False  SteelGround
# Shuckle                  230      5           2      False      BugRock
# AggronMega Aggron         80     50           3      False          NaN

# %% [markdown]
# ### 5. Which poison pokemon has the strongest attack ?

# %%
#your code here
d1=df[df['Type 2']=='Poison']
d2=df[df['Type 1']=='Poison']
d=pd.concat([d1,d2]).drop_duplicates()
d
# Out:
#                        Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur               Grass    Poison    318  45      49       49       65
# Ivysaur                 Grass    Poison    405  60      62       63       80
# Venusaur                Grass    Poison    525  80      82       83      100
# VenusaurMega Venusaur   Grass    Poison    625  80     100      123      122
# Weedle                    Bug    Poison    195  40      35       30       20
# ...                       ...       ...    ...  ..     ...      ...      ...
# Toxicroak              Poison  Fighting    490  83     106       65       86
# Trubbish               Poison       NaN    329  50      50       62       40
# Garbodor               Poison       NaN    474  80      95       82       60
# Skrelp                 Poison     Water    320  50      60       60       60
# Dragalge               Poison    Dragon    494  65      75       90       97
#
# ...

# %%
d[d['Attack']==d['Attack'].max()]
# Out:
#                       Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# BeedrillMega Beedrill    Bug  Poison    495  65     150       40       15
#
#                        Sp. Def  Speed  Generation  Legendary       Type
# Name
# BeedrillMega Beedrill       80    145           1      False  BugPoison

# %% [markdown]
# ### 6. Using seaborn make different types of plots, observe the trend and answer the questions given in the form.

# %%
#your code here
import seaborn as sns
sns.set(style='white', rc={'figure.figsize':(14,10)})
sns.countplot(df['Type 1'])
# Out:
# /home/vinit/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Type 1', ylabel='count'>

# %%
#your code here
sns.countplot(df['Type 2'])
# Out:
# /home/vinit/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Type 2', ylabel='count'>

# %%
#your code here
sns.countplot(df['Generation'])
# Out:
# /home/vinit/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Generation', ylabel='count'>

# %%
d=df[df['Legendary']]
sns.countplot(d['Generation'])
# Out:
# /home/vinit/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Generation', ylabel='count'>

# %% [markdown]
# ### 7. Which is the second fastest non-legendary 'Ghost' type pokemon from 4th generation ?

# %%
#your code here
d=df[df['Generation']==4]
d=d[d['Legendary']==False]
d1=d[d['Type 1']=='Ghost']
d2=d[d['Type 2']=='Ghost']
d=pd.concat([d1,d2]).drop_duplicates()
d
# Out:
#              Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Drifloon      Ghost  Flying    348   90      50       34       60       44
# Drifblim      Ghost  Flying    498  150      80       44       90       54
# Mismagius     Ghost     NaN    495   60      60       60      105      105
# Spiritomb     Ghost    Dark    485   50      92      108       92      108
# Dusknoir      Ghost     NaN    525   45     100      135       65      135
# Froslass        Ice   Ghost    480   70      80       70       80       70
# Rotom      Electric   Ghost    440   50      50       77       95       77
#
#            Speed  Generation  Legendary           Type
# Name
# Drifloon      70           4      False    GhostFlying
# Drifblim      80           4      False    GhostFlying
# Mismagius    105           4      False            NaN
# Spiritomb     35           4      False      GhostDark
# Dusknoir      45           4      False            NaN
# ...

# %% [markdown]
# ### 8. How many non-legendary pokemons have stronger defence but weaker attack than Charizard?

# %%
#your code here
d=df[df.index=='Charizard']
d
# Out:
#           Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Charizard   Fire  Flying    534  78      84       78      109       85    100
#
#            Generation  Legendary        Type
# Name
# Charizard           1      False  FireFlying

# %%
a=df[df['Legendary']==False]
a=a[a['Defense']>78]
a=a[a['Attack']<84]
a
# Out:
#                      Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Venusaur              Grass  Poison    525  80      82       83      100
# Wartortle             Water     NaN    405  59      63       80       65
# Blastoise             Water     NaN    530  79      83      100       85
# PidgeotMega Pidgeot  Normal  Flying    579  83      80       80      135
# Sandshrew            Ground     NaN    300  50      75       85       20
# ...                     ...     ...    ...  ..     ...      ...      ...
# Clawitzer             Water     NaN    500  71      73       88      120
# Carbink                Rock   Fairy    500  50      50      150       50
# Klefki                Steel   Fairy    470  57      80       91       80
# Bergmite                Ice     NaN    304  55      69       85       32
# Noivern              Flying  Dragon    535  85      70       80       97
#
#                      Sp. Def  Speed  Generation  Legendary          Type
# Name
# ...

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, here are some bonus questions that you can try to further deepen your understanding of the topic!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Which pokemon has the highest combined value of Attack and Sp. Atk ?

# %%
#your code here

# %% [markdown]
# ### Which type of legendary pokemons are the most common?

# %%
#your code here

# %% [markdown]
# ### How many generation-3, non-legendary pokemons have higher HP than the weakest generation-6, legendary pokemon?

# %%
#your code here

# %% [markdown]
# ### Print out the third slowest pokemon(s) in the dataset.

# %%
#your code here

# %% [markdown]
# ### Which pokemon type has the highest average HP?

# %%
#your code here
